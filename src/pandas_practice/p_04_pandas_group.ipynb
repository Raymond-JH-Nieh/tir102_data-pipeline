# %%
import pandas as pd

# %%
file_path = "/workspaces/tir102_data-pipeline/resource/Holding data.csv"
df = pd.read_csv(file_path, nrows=1000000)

# %%
df.groupby("portno") #do nothing only show memory location

# %%
df.groupby("portno").size()
# Out:
# portno
# 2998623    351
# 2998638     77
# 2998809     70
# 2998821     54
# 2999052      2
#           ...
# 309260a      2
# 309260d    514
# 3092616      1
# 3092619    403
# 3092652     27
# Length: 3867, dtype: int64

# %%
# df[df["portno" == "2999052"]]
df.groupby("portno").get_group("2999052")
# Out:
#       portno   report_dt  security_rank      eff_dt  percent_tna  nbr_shares  \
# 552  2999052  2020/10/31            282  2021/01/08         0.05    525000.0
# 553  2999052  2020/10/31            352  2021/01/08         0.03    335000.0
#
#      market_val                                     security_name     cusip
# 552   525071.74   Hewlett Packard Enterprise Co .954% 05-OCT-2021  42824CBB
# 553   330737.56  Ford Motor Credit Company LLC 1.044% 05-APR-2021  345397YY

# %%
"""
select
    portno,
    perent_tna,
    count(1)
from table
group by portno, percent_tna
"""
df.groupby(["portno", "percent_tna"]).size()
# Out:
# portno   percent_tna
# 2998623  -0.34           1
#          -0.17           1
#          -0.02           1
#           0.00          19
#           0.01           8
#                         ..
# 3092652   0.61           3
#           0.62           1
#           0.63           1
#           3.01           1
#           101.93         1
# Length: 184136, dtype: int64

# %%
df.groupby(["percent_tna", "portno"]).size() #groupby有順序性
# Out:
# percent_tna  portno
# -200.00      3086562    1
# -199.90      3086604    1
# -197.20      3087462    1
# -176.40      307545c    1
# -173.40      3069606    1
#                        ..
#  299.85      3086556    1
#  299.94      3086604    1
#  300.01      3086607    1
#  300.04      3086562    1
#  300.08      308655c    1
# Length: 184136, dtype: int64

# %%
df.groupby(["percent_tna", "portno"]).sum()
# Out:
#                       report_dt  security_rank      eff_dt    nbr_shares  \
# percent_tna portno
# -200.00     3086562  2020/12/31              2  2021/01/08 -8.667746e+07
# -199.90     3086604  2020/12/31              2  2021/01/08 -4.889844e+09
# -197.20     3087462  2020/11/30              4  2021/01/08 -5.900000e+03
# -176.40     307545c  2020/11/30            535  2021/01/08 -3.740000e+02
# -173.40     3069606  2020/11/30            660  2021/01/08 -5.910000e+03
# ...                         ...            ...         ...           ...
#  299.85     3086556  2020/12/31              1  2021/01/08  6.097380e+07
#  299.94     3086604  2020/12/31              1  2021/01/08  7.105212e+07
#  300.01     3086607  2020/12/31              1  2021/01/08  2.904950e+08
#  300.04     3086562  2020/12/31              1  2021/01/08  1.588645e+08
#  300.08     308655c  2020/12/31              1  2021/01/08  8.666786e+07
#
#                        market_val                  security_name cusip
# ...

# %%
df.groupby(["portno","percent_tna"]).sum()
# Out:
#                                                              report_dt  \
# portno  percent_tna
# 2998623 -0.34                                               2020/11/30
#         -0.17                                               2020/11/30
#         -0.02                                               2020/11/30
#          0.00        2020/11/302020/11/302020/11/302020/11/302020/1...
#          0.01        2020/11/302020/11/302020/11/302020/11/302020/1...
# ...                                                                ...
# 3092652  0.61                           2020/12/312020/12/312020/12/31
#          0.62                                               2020/12/31
#          0.63                                               2020/12/31
#          3.01                                               2020/12/31
#          101.93                                             2020/12/31
#
#                      security_rank  \
# portno  percent_tna
# ...

# %%
df.groupby(["percent_tna", "portno"]).sum().sort_values("percent_tna", ascending=False) #
# Out:
#                       report_dt  security_rank      eff_dt    nbr_shares  \
# percent_tna portno
#  300.08     308655c  2020/12/31              1  2021/01/08  8.666786e+07
#  300.04     3086562  2020/12/31              1  2021/01/08  1.588645e+08
#  300.01     3086607  2020/12/31              1  2021/01/08  2.904950e+08
#  299.94     3086604  2020/12/31              1  2021/01/08  7.105212e+07
#  299.85     3086556  2020/12/31              1  2021/01/08  6.097380e+07
# ...                         ...            ...         ...           ...
# -173.40     3069606  2020/11/30            660  2021/01/08 -5.910000e+03
# -176.40     307545c  2020/11/30            535  2021/01/08 -3.740000e+02
# -197.20     3087462  2020/11/30              4  2021/01/08 -5.900000e+03
# -199.90     3086604  2020/12/31              2  2021/01/08 -4.889844e+09
# -200.00     3086562  2020/12/31              2  2021/01/08 -8.667746e+07
#
#                        market_val                  security_name cusip
# ...

# %%
df.groupby(["portno", "percent_tna"]).sum().sort_values("report_dt", ascending=False)
# Out:
#                                                              report_dt  \
# portno  percent_tna
# 3062442 0.00         2020/12/312020/12/312020/12/312020/12/312020/1...
# 307883d 0.00         2020/12/312020/12/312020/12/312020/12/312020/1...
# 3092256 0.00         2020/12/312020/12/312020/12/312020/12/312020/1...
# 3062436 0.01         2020/12/312020/12/312020/12/312020/12/312020/1...
# 3092256 0.01         2020/12/312020/12/312020/12/312020/12/312020/1...
# ...                                                                ...
# 307465b 1.26                                                2011/04/30
# 3077241 1.87                                                2011/04/30
# 307483b 1.87                                                2011/04/30
# 3069018 0.62                                                2010/12/31
# 3073329 2.53                                                2010/12/31
#
#                      security_rank  \
# portno  percent_tna
# ...
